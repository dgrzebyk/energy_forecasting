# %% [markdown]
# # Predicting Wind Turbine Yield
# This notebook is based on the conlusions in the Exploratory Data Analysis and contains several machine learning models predicting active power generation. This approach is an alternative to the time series analysis and ARIMA model developed in a separate notebook. The largest difference is this notebook utilizes multivariate techniques while ARIMA is a univariate model.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Loading the data

# %%
feature_units = pd.read_csv("kaggle_dataset/feature_units.csv")
features = pd.read_csv("kaggle_dataset/features.csv", index_col="Timestamp")
features.index = pd.to_datetime(features.index)

power = pd.read_csv("kaggle_dataset/power.csv", index_col="Timestamp")
power.index = pd.to_datetime(power.index)

# %%
feature_units.shape, features.shape, power.shape
# Out:
# ((77, 2), (154262, 76), (136730, 1))

# %%
features.index.min(), features.index.max()
# Out:
# (Timestamp('2019-01-01 00:00:00'), Timestamp('2021-12-14 23:50:00'))

# %%
dataset_days = round(features.index.shape[0] / (6*24))
print(f"This dataset consists of {dataset_days} days")
# Out:
# This dataset consists of 1071 days

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ## Feature Engineering
# Introducing time as feature, transforming angles using sin() and cos() for 359 deg and 0 deg to be treated similarly.

# %% [markdown]
# ## Modeling
